# %% [markdown]
# # 시스템 점검

# %%
import sys
print(sys.version)
print(sys.platform)
# Out:
# 3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]
# win32

# %%
import site
site.getsitepackages()
# Out:
# ['c:\\Users\\102\\anaconda3', 'c:\\Users\\102\\anaconda3\\lib\\site-packages']

# %% [markdown]
# # 연령별 인구 분석

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

male = []
female = []


name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            male.append(int(row[i].replace(',', '')))
        for i in range(106, 207) :
            female.append(int(row[i].replace(',', '')))
        break

f.close()

plt.rc('font', family ='Malgun Gothic')

plt.plot(male, label='male', color='b')
plt.plot(female, label='female', color='r')

plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.legend()
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

diff = []

name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            diff.append(int(row[i].replace(',', '')) - int(row[i+103].replace(',', '')))
        break

f.close()

# plt.rc('font', family ='Malgun Gothic')


plt.bar(range(len(diff)), diff)

plt.xlabel('Population')
plt.ylabel('Age')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

male = []
female = []

name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            male.append(int(row[i].replace(',', '')))
            female.append(int(row[i + 103].replace(',', '')))        
        break

f.close()

plt.rc('font', family ='Malgun Gothic')

plt.scatter(male, female)
plt.xlabel('Male')
plt.ylabel('Female')
plt.grid(True)
plt.show()

# %%
import csv
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

male = []
female = []

name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            male.append(int(row[i].replace(',', '')))
            female.append(int(row[i + 103].replace(',', '')))        
        break

f.close()

plt.rc('font', family ='Malgun Gothic')

plt.scatter(male, female, c=range(len(male)), alpha=0.7, cmap='jet')
plt.colorbar()
plt.plot(range(max(male)),range(max(male)), 'g')

plt.xlabel('Male')
plt.ylabel('Female')
plt.grid(True)
plt.show()

# %%
import csv, math
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

male = []
female = []
size = []

name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            male.append(int(row[i].replace(',', '')))
            female.append(int(row[i + 103].replace(',', '')))        
            size.append(math.sqrt(int(row[i].replace(',', '')) + int(row[i+103].replace(',', ''))))
        break

f.close()

plt.rc('font', family ='Malgun Gothic')
plt.figure(figsize=(10, 5))
plt.scatter(male, female, c=range(len(male)), alpha=0.7, cmap='jet', s=size)
plt.colorbar()
plt.plot(range(max(male)),range(max(male)), 'g')

plt.xlabel('Male')
plt.ylabel('Female')
plt.grid(True)
plt.show()

# %%
import csv, math
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

header = next(data)

male = []
female = []
size = []

name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            male.append(int(row[i].replace(',', '')))
            female.append(int(row[i + 103].replace(',', '')))        
            size.append(int(row[i].replace(',', '')) + int(row[i+103].replace(',', '')))
        break

f.close()

plt.rc('font', family ='Malgun Gothic')
plt.figure(figsize=(10, 5))
plt.scatter(male, female, c=range(len(male)), alpha=0.7, cmap='jet', s=size)
plt.colorbar()
plt.plot(range(max(male)),range(max(male)), 'g')

plt.xlabel('Male')
plt.ylabel('Female')
plt.grid(True)
plt.show()

# %%
import csv, math
import matplotlib.pyplot as plt

f = open('gender.csv', encoding='cp949')
data = csv.reader(f)

# header = next(data)
next(data)

male = []
female = []
size = []

name = input('궁금한 동네를 입력하세요: ')
# 제주특별자치도

for row in data :
    if name in row[0] :
        for i in range(3, 104) :
            male.append(int(row[i].replace(',', '')))
            female.append(int(row[i + 103].replace(',', '')))        
            size.append((int(row[i].replace(',', '')) + int(row[i+103].replace(',', '')))/20)
        break

f.close()

plt.rc('font', family ='Malgun Gothic')
plt.figure(figsize=(10, 5))
plt.scatter(male, female, c=range(len(male)), alpha=0.7, cmap='jet', s=size)
plt.colorbar()
plt.plot(range(max(male)),range(max(male)), 'g')

plt.xlabel('Male')
plt.ylabel('Female')
plt.grid(True)
plt.show()

print(male[:10])
print(female[:10])
# Out:
# [1611, 1891, 2065, 2291, 2491, 2768, 3084, 3481, 3572, 3614]
# [1598, 1757, 1955, 2139, 2430, 2604, 2843, 3251, 3400, 3480]

# %%
import csv, math
import matplotlib.pyplot as plt
import random

x = [random.randint(1, 30) for i in range(10)]
y = [random.randint(1, 50) for i in range(10)]
size = [random.randint(10, 20)*10 for i in range(10)]

x = [random.randint(1, 30) for i in range(10)]
y = [random.randint(1, 50) for i in range(10)]
size = [random.randint(10, 20)*10 for i in range(10)]

print(x)
print(y)
print(size)

plt.figure(figsize=(10, 4))
plt.scatter(x, y, c=range(len(x)), alpha=0.3, cmap='jet', s=size)
plt.colorbar()
plt.plot(range(max(x)),range(max(x)), 'g')

plt.xlabel('X')
plt.ylabel('Y')
plt.grid(True)
plt.show()
# Out:
# [11, 7, 16, 29, 7, 6, 27, 21, 2, 11]
# [24, 20, 47, 38, 49, 22, 35, 16, 33, 25]
# [110, 170, 180, 150, 150, 130, 180, 100, 200, 120]

# %% [markdown]
# # 지하철 데이터 내려받기
# - subwayfee.csv
# - subwaytime.csv

# %% [markdown]
# # 그래프 이미지 저장하기

# %%
import matplotlib.pyplot as plt

x = [0, 2, 4, 5]
y = [5, 10, 15, 20]

plt.bar(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 2, 4, 5]
y = [5, 10, 15, 20]

plt.bar(x, y)
plt.savefig('막대그래프.png')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 2, 4, 5]
y = [5, 10, 15, 20]

plt.bar(x, y)
plt.savefig('막대그래프_기본.png')
plt.savefig('막대그래프_DPI_50.png', dpi=50)
plt.savefig('막대그래프_DPI_200.png', dpi=200)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [0, 2, 4, 5]
y = [5, 10, 15, 20]

plt.bar(x, y)
plt.savefig('막대그래프_facecolor.png', facecolor='skyblue')
plt.show()

# %% [markdown]
# # 지하철 데이터 유임 무임 승차 분석

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)

for row in data :
    print(row)
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['2023-10', '1호선', '0150', '서울역', '1,414,759', '1,325,225', '228,199', '221,362']
# ['2023-10', '1호선', '0151', '시청', '680,015', '688,576', '110,873', '109,588']
# ['2023-10', '1호선', '0152', '종각', '934,182', '912,219', '153,323', '142,417']
# ['2023-10', '1호선', '0153', '종로3가', '505,893', '450,857', '318,029', '290,405']
# ['2023-10', '1호선', '0154', '종로5가', '496,473', '499,265', '268,981', '260,177']
# ['2023-10', '1호선', '0155', '동대문', '240,537', '233,806', '133,504', '134,891']
# ['2023-10', '1호선', '0156', '신설동', '285,710', '274,653', '125,851', '123,331']
# ['2023-10', '1호선', '0157', '제기동', '229,494', '219,321', '284,154', '303,921']
# ['2023-10', '1호선', '0158', '청량리(서울시립대입구)', '373,168', '363,785', '284,133', '286,861']
# ['2023-10', '1호선', '0159', '동묘앞', '158,633', '169,937', '179,081', '180,728']
# ['2023-10', '2호선', '0201', '시청', '661,611', '620,522', '64,629', '59,210']
# ...

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))
    print(row)

f.close()
# Out:
# ['2023-10', '1호선', '0150', '서울역', 1414759, 1325225, 228199, 221362]
# ['2023-10', '1호선', '0151', '시청', 680015, 688576, 110873, 109588]
# ['2023-10', '1호선', '0152', '종각', 934182, 912219, 153323, 142417]
# ['2023-10', '1호선', '0153', '종로3가', 505893, 450857, 318029, 290405]
# ['2023-10', '1호선', '0154', '종로5가', 496473, 499265, 268981, 260177]
# ['2023-10', '1호선', '0155', '동대문', 240537, 233806, 133504, 134891]
# ['2023-10', '1호선', '0156', '신설동', 285710, 274653, 125851, 123331]
# ['2023-10', '1호선', '0157', '제기동', 229494, 219321, 284154, 303921]
# ['2023-10', '1호선', '0158', '청량리(서울시립대입구)', 373168, 363785, 284133, 286861]
# ['2023-10', '1호선', '0159', '동묘앞', 158633, 169937, 179081, 180728]
# ['2023-10', '2호선', '0201', '시청', 661611, 620522, 64629, 59210]
# ['2023-10', '2호선', '0202', '을지로입구', 1250870, 1276706, 106095, 98286]
# ['2023-10', '2호선', '0203', '을지로3가', 610279, 602191, 74883, 73373]
# ['2023-10', '2호선', '0204', '을지로4가', 320763, 326448, 79341, 78130]
# ...

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

print(header)

rate = 0
max_rate = 0

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))

    rate = row[4] / row[6]
    if rate > max_rate :
        max_rate = rate
    

f.close()
print(max_rate)
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12332\2990471682.py in <module>
#      13         row[i] = int(row[i].replace(',', ''))
#      14
# ---> 15     rate = row[4] / row[6]
#      16     if rate > max_rate :
#      17         max_rate = rate
#
# ZeroDivisionError: division by zero

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

print(header)

rate = 0
max_rate = 0

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))

    if row[6] == 0:
        print(row)  

f.close()
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['2023-10', '경의선', '1295', '김포공항', 3, 0, 0, 0]
# ['2023-10', '경의선', '1296', '계양', 5, 0, 0, 0]
# ['2023-10', '6호선', '2649', '신내', 10, 0, 0, 0]

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

print(header)

rate = 0
max_rate = 0

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))

    if row[6] != 0 :
        rate = row[4] / row[6]
        if rate > max_rate :
            max_rate = rate
            print(row, max_rate)
f.close()
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['2023-10', '1호선', '0150', '서울역', 1414759, 1325225, 228199, 221362] 6.199672215916809
# ['2023-10', '2호선', '0201', '시청', 661611, 620522, 64629, 59210] 10.237060762196537
# ['2023-10', '2호선', '0202', '을지로입구', 1250870, 1276706, 106095, 98286] 11.790093783872944
# ['2023-10', '2호선', '0209', '한양대', 332911, 367396, 15428, 16391] 21.57836401348198
# ['2023-10', '분당선', '1031', '복정', 31, 0, 1, 0] 31.0

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

print(header)

rate = 0
max_rate = 0

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))

    if row[6] != 0 :
        rate = row[4] / row[6]
        if rate > max_rate :
            max_rate = rate
            # print(row, round(max_rate, 2))
            print(row, f'{max_rate:.2f}')
f.close()
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['2023-10', '1호선', '0150', '서울역', 1414759, 1325225, 228199, 221362] 6.20
# ['2023-10', '2호선', '0201', '시청', 661611, 620522, 64629, 59210] 10.24
# ['2023-10', '2호선', '0202', '을지로입구', 1250870, 1276706, 106095, 98286] 11.79
# ['2023-10', '2호선', '0209', '한양대', 332911, 367396, 15428, 16391] 21.58
# ['2023-10', '분당선', '1031', '복정', 31, 0, 1, 0] 31.00

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

print(header)

rate = 0
max_rate = 0

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))

    if row[6] != 0 and row[4] + row[6] > 100000:
        rate = row[4] / (row[4] + row[6]) 
        if rate > max_rate :
            max_rate = rate
            # print(row, round(max_rate, 2))
            print(row, f'{max_rate:.2f}')
f.close()
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['2023-10', '1호선', '0150', '서울역', 1414759, 1325225, 228199, 221362] 0.86
# ['2023-10', '2호선', '0201', '시청', 661611, 620522, 64629, 59210] 0.91
# ['2023-10', '2호선', '0202', '을지로입구', 1250870, 1276706, 106095, 98286] 0.92
# ['2023-10', '2호선', '0209', '한양대', 332911, 367396, 15428, 16391] 0.96

# %%
import csv
f = open('subwayfee.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

print(header)

rate = 0
max_rate = 0

for row in data :
    for i in range(4, 8):
        row[i] = int(row[i].replace(',', ''))

    if row[6] != 0 and row[4] + row[6] > 100000:
        rate = row[4] / (row[4] + row[6]) 
        if rate > 0.92 :
            max_rate = rate
            # print(row, round(max_rate, 2))
            print(row, f'{max_rate:.2f}')
f.close()
# Out:
# ['사용월', '호선명', '역ID', '지하철역', '유임승차', '유임하차', '무임승차', '무임하차']
# ['2023-10', '2호선', '0202', '을지로입구', 1250870, 1276706, 106095, 98286] 0.92
# ['2023-10', '2호선', '0209', '한양대', 332911, 367396, 15428, 16391] 0.96
# ['2023-10', '2호선', '0222', '강남', 2015080, 1972389, 158673, 138379] 0.93
# ['2023-10', '2호선', '0238', '합정', 901235, 988385, 73996, 75278] 0.92
# ['2023-10', '2호선', '0239', '홍대입구', 2021040, 2210524, 103476, 101120] 0.95
# ['2023-10', '4호선', '0424', '명동', 954255, 1033645, 82704, 85973] 0.92
# ['2023-10', '경부선', '1001', '서울역', 291012, 87690, 19004, 3902] 0.94
# ['2023-10', '5호선', '2527', '여의도', 723509, 782528, 57967, 55299] 0.93
# ['2023-10', '5호선', '2528', '여의나루', 484566, 582461, 37150, 38173] 0.93
# ['2023-10', '6호선', '2624', '상수', 292099, 334612, 23133, 23217] 0.93
# ['2023-10', '6호선', '2632', '한강진', 283033, 337531, 18585, 18594] 0.94
# ['2023-10', '9호선', '4115', '여의도', 740691, 718885, 53432, 49560] 0.93
# ['2023-10', '9호선', '4125', '신논현', 841939, 828551, 56884, 55335] 0.94
# ...
