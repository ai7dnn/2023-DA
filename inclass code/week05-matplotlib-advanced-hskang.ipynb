# %% [markdown]
# # matplotlib 중급

# %% [markdown]
# ## 시스템 점검

# %%
import sys
sys.version
# Out:
# '3.9.13 (main, Aug 25 2022, 23:51:50) [MSC v.1916 64 bit (AMD64)]'

# %%
sys.path
# Out:
# ['C:\\2023-A-DA',
#  'C:\\Users\\102\\anaconda3\\python39.zip',
#  'C:\\Users\\102\\anaconda3\\DLLs',
#  'C:\\Users\\102\\anaconda3\\lib',
#  'C:\\Users\\102\\anaconda3',
#  '',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\102\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\102\\.ipython']

# %% [markdown]
# ## plot() 복습
# - 한글처리

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# 폰트 설정
mpl.rc('font', family='Malgun Gothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

plt.plot([1, 2, 3, 4], [10, 20, 30, 40])
plt.title('plotting')
plt.show()

# %% [markdown]
# ## figsize()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(5, 3))
plt.plot()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus'] = False

# plt.figure(figsize=(7, 4))
plt.figure(figsize=(5, 3))

x = np.linspace(-2 * np.pi, 2 * np.pi, 200) # 0에서 2*pi까지 경계선을 포함해 200개ㅐ의 수로 등분(199등분)
plt.plot(x, np.sin(x)*10, ':r')
plt.plot(x, x**2)
plt.plot(x, 2 * x**2 - 3*x)

# 전체 그림 범위 지정
plt.xlim(-10, 10)
plt.ylim(-30, 120)

plt.grid(True)
plt.title('다양한 그래프')
plt.show()

# %% [markdown]
# ## histogram 도수분포표
# - 인자 rwidth=0.9: 도수 막대 중간에 공간을 비움

# %%
import matplotlib.pyplot as plt

plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 7, 8, 10], rwidth=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 7, 8, 10], bins=3, rwidth=0.9)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

arrays, bins, patches = plt.hist([1, 1, 2, 3, 4, 5, 6, 6, 8, 10], bins=np.arange(0.5, 11.5), rwidth=0.8)
plt.show()

# %%
arrays
# Out:
# array([2., 1., 1., 1., 1., 2., 0., 1., 0., 1.])

# %%
bins
# Out:
# array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5])

# %%
patches
# Out:
# <BarContainer object of 10 artists>

# %% [markdown]
# ## random.randint(a, b)

# %%
import random
random.randint(1, 6)
# Out:
# 4

# %%
import random
random.randrange(1, 6)
# Out:
# 3

# %%
import random as rd

dice=[]
for i in range(5):
    dice.append(rd.randint(1, 6))

dice
# Out:
# [6, 4, 3, 2, 4]

# %% [markdown]
# ### 리스트 컴프리헨션

# %%
dice = [rd.randint(1, 6) for i in range(10)]
dice
# Out:
# [2, 2, 2, 4, 3, 1, 1, 2, 3, 6]

# %%
rd.choices(range(1, 7), k=5)
# Out:
# [6, 3, 4, 4, 5]

# %%
import random
import matplotlib.pyplot as plt

dice = []

for i in range(1000000):
    dice.append(random.randint(1, 6))

plt.hist(dice, bins=6)
# plt.hist(dice)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result = []
for i in range(13):
    result.append(random.randint(1, 1000))
    
print(sorted(result))

plt.boxplot(result, whis=.1)
# plt.boxplot(result)
plt.show()
# Out:
# [111, 129, 159, 248, 253, 477, 512, 601, 779, 866, 895, 932, 982]

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))

plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result1 = random.choices(range(1, 500), k=13)
result2 = random.choices(range(501, 1000), k=13)

plt.boxplot(result1)
plt.boxplot(result2)
plt.show()

# %%
import matplotlib.pyplot as plt
import random

result1 = []
result2 = []
for i in range(13):
    result1.append(random.randint(1, 500))
    result2.append(random.randint(501, 1000))
    
plt.boxplot([result1, result2])
plt.show()

# %% [markdown]
# ## plt.figure(figsize=(m, n))

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(10)

f1 = plt.figure(figsize=(10, 2))
plt.plot(np.random.randn(100))

plt.title("figure size : (10, 2)")
plt.show()

# %% [markdown]
# ## plt.subplot()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(7, 3))
plt.subplot(2, 3, 1)
plt.subplot(2, 3, 5)
plt.subplot(2, 3, 6)
# plt.plot()
# plt.show()
# Out:
# <AxesSubplot:>

# %%
ax1 = plt.subplot(2, 1, 1)
plt.plot(np.random.randint(1, 10, 10), 'yo-')
plt.title('A tale of 2 subplots')
plt.ylabel('Damped oscillation')
# print(ax1)

#ax2 = plt.subplot(2, 1, 2)
ax2 = plt.subplot(2, 1, 2)
plt.plot(np.arange(10), np.arange(10)*2, 'r.-')
plt.xlabel('time (s)')
plt.ylabel('Undamped')
# print(ax2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## plt.subplots()

# %%
import matplotlib.pyplot as plt

# fig, axes = plt.subplots(2, 3)  # 2행 2열의 서브플롯
plt.subplots(2, 4)  # 2행 2열의 서브플롯

# axes[0, 0].plot()
# axes[0, 1].plot()
# axes[1, 0].plot()
# axes[1, 1].plot()

plt.show()

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, 2)  # 2행 2열의 서브플롯
plt.figure(figsize=(6, 4))

axes[0, 0].plot([1, 2, 3, 4])
axes[0, 0].set_title("Subplot 1")

axes[0, 1].plot([4, 3, 2, 1])
axes[0, 1].set_title("Subplot 2")

axes[1, 0].hist([1, 2, 2, 3, 3, 3, 4, 4, 4, 4], bins=5)
axes[1, 0].set_title("Subplot 3")

axes[1, 1].scatter([1, 2, 3, 4], [4, 3, 2, 1])
axes[1, 1].set_title("Subplot 4")

plt.tight_layout()
plt.show()

# %%
plt.subplots(2, 3)
plt.show()

# %%
plt.subplots(2, 3, sharex=True)
plt.show()

# %%
plt.subplots(2, 3, sharey=True)
plt.show()

# %%
plt.subplots(2, 3, sharex=True, sharey=True)
plt.show()

# %% [markdown]
# ## fig.add_subplot()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 5))
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(7, 5))

#ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
plt.plot(np.random.randn(50).cumsum(), 'g--')

ax3 = fig.add_subplot(2, 2, 3)
plt.plot(np.random.randn(50), 'm--')
